# %% [markdown]
# ## Need to download precip data as well

# %%
import aairtd as ird

station_list = ird.get_stations_from_networks()
output_directory = "station_data"
ird.download_station_data(station_list, output_directory)
# Out:
# Downloaded data for station: PADK
# Downloaded data for station: PAKH
# Downloaded data for station: PFZK
# Downloaded data for station: PAUT
# Downloaded data for station: PALP
# Downloaded data for station: PAFM
# Downloaded data for station: PAKP
# Downloaded data for station: PANC
# Downloaded data for station: PAGN
# Downloaded data for station: PANI
# Downloaded data for station: PANT
# Downloaded data for station: PANV
# Downloaded data for station: PARC
# Downloaded data for station: PAAK
# Downloaded data for station: PATQ
# Downloaded data for station: PABR
# Downloaded data for station: PABA
# Downloaded data for station: PABE
# Downloaded data for station: PABT
# Downloaded data for station: PALV
# Downloaded data for station: PABV
# Downloaded data for station: PFKT
# Downloaded data for station: PABL
# Downloaded data for station: PATW
# Downloaded data for station: PALU
# Downloaded data for station: PAEH
# Downloaded data for station: PACZ
# ...
